# %%
message = "Hello Python World!"
print(message)
# Out:
# Hello Python World!

# %%
message = "hello world"
print(message)

message = "Hello python Crash course world!"
print(message)
# Out:
# hello world
# Hello python Crash course world!

# %%
time = "it is 11 ok right now"
print(time)
# Out:
# it is 11 ok right now

# %%
theme = "anaconder pride"
print(theme.title())
print(theme.upper())
print(theme.lower())
# Out:
# Anaconder Pride
# ANACONDER PRIDE
# anaconder pride

# %%
first_name = "Easteric"
last_name = "Empeh"

print(first_name + " " + last_name);
# Out:
# Easteric Empeh

# %%
first = "easteric"
last = "empeh"
fullname = first + " " + last

message = "Hello, " + fullname.title() + "!"

print(message)
# Out:
# Hello, Easteric Empeh!

# %%
print("python")
print("\tpython")
# Out:
# python
# 	python

# %%
print("Languages:\n\tPython\n\tJava\n\tJavascript")
# Out:
# Languages:
# 	Python
# 	Java
# 	Javascript

# %%
language = " python "
lang = language.rstrip().lstrip()
print(language)
print(lang)
# Out:
#  python
# python

# %%
name = "easteric"
lang = "python"

message = "hello " + name.title() +"," + " would you like to learn some " + lang + " today?"
print(message)
# Out:
# hello Easteric, would you like to learn some python today?

# %%
# Out:
# Easteric Empeh
# EASTERIC EMPEH
# easteric empeh

# %%
quote = "there is no reward for being a nice person"
person = "Easteric"

full = person + " once said, " + '"' + quote + '"'
print(full)
# Out:
# Easteric once said, "there is no reward for being a nice person"

# %%
# Out:
# 0.30000000000000004

# %%
age = 22
message = "happy " + str(age) + "nd birthday!"
print(message)
# Out:
# happy 22nd birthday!

# %%
print(3/2)
# Out:
# 1.5

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
bicycles = ['trek', 'royal', 'line', 'rough']
print(bicycles)
# Out:
# ['trek', 'royal', 'line', 'rough']

# %%
print(bicycles[0])
# Out:
# trek

# %%
message = "My first bicycle was a " + bicycles[0].title() + "."

# %%
print(message)
# Out:
# My first bicycle was a Trek.

# %%
bicycles[0] = "runner"
print(bicycles)
# Out:
# ['runner', 'royal', 'line', 'rough']

# %%
bicycles.append("apsonic")
print(bicycles)
# Out:
# ['runner', 'royal', 'line', 'rough', 'apsonic']

# %%
bicycles.pop()
# Out:
# 'apsonic'

# %%
print(bicycles)
# Out:
# ['runner', 'royal', 'line', 'rough']

# %%
new = bicycles.pop()
print(new)
# Out:
# rough

# %%
bicycles.insert(0,"odada")
print(bicycles)
# Out:
# ['odada', 'runner', 'royal', 'line']

# %%
del bicycles[0]

# %%
print(bicycles)
# Out:
# ['runner', 'royal', 'line']

# %%
popped_cycle = bicycles.pop()

# %%
print(popped_cycle)
# Out:
# line

# %%
print(bicycles)
# Out:
# ['runner', 'royal']

# %%
bicycles.remove("runner")
print(bicycles)
# Out:
# ['royal']

# %%
cars = ["Bmw", "Audi", "Toyota", "Kia"]
print("here is the original list:")
print(cars)

print("\nHere is the sorted list:")
print(sorted(cars))

print("\nhere is the original list again:")
print(cars)
# Out:
# here is the original list:
# ['Bmw', 'Audi', 'Toyota', 'Kia']
#
# Here is the sorted list:
# ['Audi', 'Bmw', 'Kia', 'Toyota']
#
# here is the original list again:
# ['Bmw', 'Audi', 'Toyota', 'Kia']

# %%
cars
print(cars)
# Out:
# ['Bmw', 'Audi', 'Toyota', 'Kia']

# %%
cars.reverse()
print(cars)
# Out:
# ['Kia', 'Toyota', 'Audi', 'Bmw']

# %%
len(cars)
# Out:
# 4

# %%
print(cars[-1])
# Out:
# Bmw

# %%
cars
# Out:
# ['Kia', 'Toyota', 'Audi', 'Bmw']

# %%
cars

for car in cars:
    print("This car is a " + car + " and it is very nice.")
# Out:
# This car is a Kia and it is very nice.
# This car is a Toyota and it is very nice.
# This car is a Audi and it is very nice.
# This car is a Bmw and it is very nice.

# %%
cars

for car in cars:
    print("This car is a " + car + " and it is very nice.")
    print("Do you want to by a " + car.upper() + "?" + "\n")
# Out:
# This car is a Kia and it is very nice.
# Do you want to by a KIA?
#
# This car is a Toyota and it is very nice.
# Do you want to by a TOYOTA?
#
# This car is a Audi and it is very nice.
# Do you want to by a AUDI?
#
# This car is a Bmw and it is very nice.
# Do you want to by a BMW?
